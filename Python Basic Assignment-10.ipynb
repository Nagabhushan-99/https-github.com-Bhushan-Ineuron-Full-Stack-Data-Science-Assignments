# %% [markdown]
# #### Q1)  How do you distingushi between shutil.copy() and shutil.copytree()

# %% [markdown]
# Ans: shutil.copy() method is used to copy the contents of a file from one file to another file/folder, it primary takes two arguments src,dest, src represents the file to be copied where as destination refers to the file/folder to where the src data should be copied, if dest is a folder name the src with exact name will be copied to the dest folder, if its a file then the contents of src will be copied to dest where dest retains it name.
# shutil.copytree() function is used to copy the entire contents of a folder to other folder. it also takes two arguments src & dest, it copies all the content recursively and stores it in dest. the important catch here is dest must not exist prior to this and it will be created during the copy operation. Permissions and times of directories are copied with shutil.copystat() and individual files are copied using shutil.copy2() by default which can be modified using copy_function attribute.

# %% [markdown]
# #### Q2) What function is used to rename files?

# %% [markdown]
# Ans: os.rename() function is used to rename files or directories using a python program, this function takes two arguments src and dest, src represents the name file/directory which we want to rename, whereas dest represents the new name of the file/directory.

# %% [markdown]
# #### Q3) What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# Ans: Shutil module provides a funciton called as shutil.rmtree() which deletes a directory and all its contents. The other functions with similar functionality are os.remove() -> removes a file, os.rmdir() removes a empty directory. The problem with these functions is once a file is deleted. it will be lost permanently, if a file is deleted accidentally using these methods there is no way we can recover the deleted file
# Where as send2trash module provides a function called send2trash.send2trash() to delete a file/directory. these methods moves the files/directories to trash folder instead of permanently deleting them. hence if a file/folder is deleted accidentally it can be still recovered from trash folder, if is deleted using the send2trash.send2trash() function. send2trash is not included with python standard libary like os & shutil modules. it needs to be installed explicitly using the command !pip install send2trash

# %% [markdown]
# #### Q4)ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

# %% [markdown]
# Ans: ZipFile Module provides a method called as zipfile.ZipFile() to read and write to zipFiles. it takes arugments lile filename and mode etc zipfile.ZipFile('filename', mode = 'r')

# %% [markdown]
# #### Q5) Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder

# %%
import os
import shutil
def search_and_copy(source,destination,extensions):
    source = os.path.abspath(source)
    destination = os.path.abspath(destination)
    for foldername, subfolder, filenames in os.walk(source):
        print(f'Folder Name ➞ {foldername}',end='\n\n')
        print(f'Sub Folders ➞ {subfolder}',end='\n\n')
        print(f'Files ➞ {filenames}',end='\n\n')
        for filename in filenames:
            fileName,extension = os.path.splitext(filename)
            if extension in extensions:
                targetFile = foldername+os.path.sep+fileName+extension
                shutil.copy(targetFile, destination)
        print(f'Files copied successfully from {source} to {destination}')

# %%
extensions = ['.pdf','.jpg','.ipynb']
source = "C:\\Users\\vasudha\\AppData\\Local\\Programs\\Python\\Python37"
destination = "C:\\Users\\vasudha\\AppData\\Local\\Programs\\Python\\Python36"
search_and_copy(source, destination, extensions)
# Out:
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37
#
# Sub Folders ➞ ['include', 'Lib', 'Scripts', 'share']
#
# Files ➞ ['back.pdf', 'china.jpg', 'filesave.pdf', 'forward.pdf', 'grace_hopper.jpg', 'hand.pdf', 'help.pdf', 'home.pdf', 'hubble_deep_field.jpg', 'matplotlib.pdf', 'move.pdf', 'nbagg_uat.ipynb', 'qt4_editor_options.pdf', 'retina.jpg', 'rocket.jpg', 'Sample.py', 'subplots.pdf', 'zoom_to_rect.pdf']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\include
#
# Sub Folders ➞ ['greenlet']
#
# Files ➞ []
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\include\greenlet
#
# Sub Folders ➞ []
#
# Files ➞ ['greenlet.h']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib
#
# Sub Folders ➞ ['site-packages']
#
# Files ➞ []
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages
#
# Sub Folders ➞ ['absl', 'absl_py-1.0.0.dist-info', 'adodbapi', 'astor', 'astor-0.8.1.dist-info', 'backports', 'backports.zoneinfo-0.2.1.dist-info', 'beautifulsoup4-4.10.0.dist-info', 'bs4', 'cached_property-1.5.2.dist-info', 'cachetools', 'cachetools-4.2.4.dist-info', 'caffe2', 'certifi', 'certifi-2021.10.8.dist-info', 'cffi', 'cffi-1.15.0.dist-info', 'charset_normalizer', 'charset_normalizer-2.0.8.dist-info', 'click', 'click-8.0.3.dist-info', 'colorama', 'colorama-0.4.4.dist-info', 'comtypes', 'comtypes-1.1.10.dist-info', 'cv2', 'cycler-0.11.0.dist-info', 'dateutil', 'docopt-0.6.2.dist-info', 'efficientnet', 'efficientnet-1.1.0.dist-info', 'engineio', 'et_xmlfile', 'et_xmlfile-1.1.0.dist-info', 'flask', 'Flask-1.1.2.dist-info', 'fontTools', 'fonttools-4.28.2.dist-info', 'gast', 'gast-0.2.2-py3.7.egg-info', 'gevent', 'gevent-1.4.0.dist-info', 'google', 'google_auth-1.35.0.dist-info', 'google_auth_oauthlib', 'google_auth_oauthlib-0.4.6.dist-info', 'google_pasta-0.2.0.dist-info', 'greenlet', 'greenlet-1.1.2.dist-info', 'grpc', 'grpcio-1.42.0.dist-info', 'h5py', 'h5py-3.6.0.dist-info', 'idna', 'idna-3.3.dist-info', 'imageio', 'imageio-2.12.0.dist-info', 'importlib_metadata', 'importlib_metadata-4.8.2.dist-info', 'isapi', 'itsdangerous', 'itsdangerous-2.0.1.dist-info', 'jinja2', 'Jinja2-3.0.3.dist-info', 'joblib', 'joblib-1.1.0.dist-info', 'js2py', 'Js2Py-0.71.dist-info', 'kavenegar-1.1.2.dist-info', 'keras_applications', 'Keras_Applications-1.0.8.dist-info', 'keras_preprocessing', 'Keras_Preprocessing-1.1.2.dist-info', 'kiwisolver-1.3.2.dist-info', 'markdown', 'Markdown-3.3.6.dist-info', 'markupsafe', 'MarkupSafe-2.0.1.dist-info', 'matplotlib', 'matplotlib-3.2.1.dist-info', 'mpl_toolkits', 'networkx', 'networkx-2.6.3.dist-info', 'numpy', 'numpy-1.16.2.dist-info', 'oauthlib', 'oauthlib-3.1.1.dist-info', 'opencv_python-4.0.0.21.dist-info', 'openpyxl', 'openpyxl-3.0.9.dist-info', 'opt_einsum', 'opt_einsum-3.3.0.dist-info', 'packaging', 'packaging-21.3.dist-info', 'pandas', 'pandas-0.24.2.dist-info', 'pasta', 'PIL', 'Pillow-7.1.2.dist-info', 'pipwin', 'pipwin-0.5.1.dist-info', 'protobuf-3.19.1.dist-info', 'pyasn1', 'pyasn1-0.4.8.dist-info', 'pyasn1_modules', 'pyasn1_modules-0.2.8.dist-info', 'pycparser', 'pycparser-2.21.dist-info', 'pyjsparser', 'pyjsparser-2.7.1.dist-info', 'pymysql', 'PyMySQL-1.0.2.dist-info', 'pyparsing', 'pyparsing-3.0.6.dist-info', 'pypiwin32-223.dist-info', 'pyprind', 'PyPrind-2.11.3.dist-info', 'pySmartDL', 'pySmartDL-1.3.4.dist-info', 'pythonwin', 'python_dateutil-2.8.2.dist-info', 'python_engineio-4.3.0.dist-info', 'pyttsx', 'pyttsx-1.1.dist-info', 'pyttsx3', 'pyttsx3-2.90.dist-info', 'pytz', 'pytz-2021.3.dist-info', 'pytz_deprecation_shim', 'pytz_deprecation_shim-0.1.0.post0.dist-info', 'PyWavelets-1.2.0.dist-info', 'pywin32-302.dist-info', 'pywin32_system32', 'pywt', 'requests', 'requests-2.26.0.dist-info', 'requests_oauthlib', 'requests_oauthlib-1.3.0.dist-info', 'rsa', 'rsa-4.8.dist-info', 'scikit_image-0.18.3.dist-info', 'scikit_learn-0.22.2.post1.dist-info', 'scipy', 'scipy-1.4.1.dist-info', 'setuptools_scm', 'setuptools_scm-6.3.2.dist-info', 'six-1.16.0.dist-info', 'skimage', 'sklearn', 'soupsieve', 'soupsieve-2.3.1.dist-info', 'SpeechRecognition-3.8.1.dist-info', 'speech_recognition', 'tensorboard', 'tensorboard-2.1.1.dist-info', 'tensorflow', 'tensorflow-2.1.0.dist-info', 'tensorflow_core', 'tensorflow_estimator', 'tensorflow_estimator-2.1.0.dist-info', 'termcolor-1.1.0-py3.7.egg-info', 'test', 'tifffile', 'tifffile-2021.11.2.dist-info', 'tomli', 'tomli-1.2.2.dist-info', 'torch', 'torch-1.10.0.dist-info', 'tqdm', 'tqdm-4.32.2.dist-info', 'typing_extensions-4.0.0.dist-info', 'tzdata', 'tzdata-2021.5.dist-info', 'tzlocal', 'tzlocal-4.1.dist-info', 'urllib3', 'urllib3-1.26.7.dist-info', 'werkzeug', 'Werkzeug-1.0.1.dist-info', 'wheel', 'wheel-0.37.0.dist-info', 'win32', 'win32com', 'win32comext', 'wrapt', 'wrapt-1.13.3.dist-info', 'zipp-3.6.0.dist-info', '__pycache__']
#
# Files ➞ ['cached_property.py', 'CHANGELOG.md', 'cycler.py', 'docopt.py', 'google_auth-1.35.0-py3.9-nspkg.pth', 'kavenegar.py', 'kiwisolver.cp37-win_amd64.pyd', 'LICENSE', 'matplotlib-3.2.1-py3.7-nspkg.pth', 'protobuf-3.19.1-py3.7-nspkg.pth', 'pylab.py', 'pythoncom.py', 'PyWin32.chm', 'pywin32.pth', 'pywin32.version.txt', 'README.md', 'six.py', 'termcolor.py', 'typing_extensions.py', 'zipp.py', '_cffi_backend.cp37-win_amd64.pyd']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl
#
# Sub Folders ➞ ['flags', 'logging', 'testing', '__pycache__']
#
# Files ➞ ['app.py', 'command_name.py', '_collections_abc.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\flags
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['argparse_flags.py', '_argument_parser.py', '_defines.py', '_exceptions.py', '_flag.py', '_flagvalues.py', '_helpers.py', '_validators.py', '_validators_classes.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\flags\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['argparse_flags.cpython-37.pyc', '_argument_parser.cpython-37.pyc', '_defines.cpython-37.pyc', '_exceptions.cpython-37.pyc', '_flag.cpython-37.pyc', '_flagvalues.cpython-37.pyc', '_helpers.cpython-37.pyc', '_validators.cpython-37.pyc', '_validators_classes.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\logging
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['converter.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\logging\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['converter.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\testing
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['absltest.py', 'flagsaver.py', 'parameterized.py', 'xml_reporter.py', '_bazelize_command.py', '_parameterized_async.py', '_pretty_print_reporter.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\testing\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['absltest.cpython-37.pyc', 'flagsaver.cpython-37.pyc', 'parameterized.cpython-37.pyc', 'xml_reporter.cpython-37.pyc', '_bazelize_command.cpython-37.pyc', '_parameterized_async.cpython-37.pyc', '_pretty_print_reporter.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['app.cpython-37.pyc', 'command_name.cpython-37.pyc', '_collections_abc.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\absl_py-1.0.0.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['AUTHORS', 'INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\adodbapi
#
# Sub Folders ➞ ['examples', 'test', '__pycache__']
#
# Files ➞ ['adodbapi.py', 'ado_consts.py', 'apibase.py', 'is64bit.py', 'license.txt', 'process_connect_string.py', 'readme.txt', 'remote.py', 'schema_table.py', 'setup.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\adodbapi\examples
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['db_print.py', 'db_table_names.py', 'xls_read.py', 'xls_write.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\adodbapi\examples\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['db_print.cpython-37.pyc', 'db_table_names.cpython-37.pyc', 'xls_read.cpython-37.pyc', 'xls_write.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\adodbapi\test
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['adodbapitest.py', 'adodbapitestconfig.py', 'dbapi20.py', 'is64bit.py', 'setuptestframework.py', 'test_adodbapi_dbapi20.py', 'tryconnection.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\adodbapi\test\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['adodbapitest.cpython-37.pyc', 'adodbapitestconfig.cpython-37.pyc', 'dbapi20.cpython-37.pyc', 'is64bit.cpython-37.pyc', 'setuptestframework.cpython-37.pyc', 'test_adodbapi_dbapi20.cpython-37.pyc', 'tryconnection.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\adodbapi\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['adodbapi.cpython-37.pyc', 'ado_consts.cpython-37.pyc', 'apibase.cpython-37.pyc', 'is64bit.cpython-37.pyc', 'process_connect_string.cpython-37.pyc', 'remote.cpython-37.pyc', 'schema_table.cpython-37.pyc', 'setup.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\astor
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['codegen.py', 'code_gen.py', 'file_util.py', 'node_util.py', 'op_util.py', 'rtrip.py', 'source_repr.py', 'string_repr.py', 'tree_walk.py', 'VERSION', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\astor\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['codegen.cpython-37.pyc', 'code_gen.cpython-37.pyc', 'file_util.cpython-37.pyc', 'node_util.cpython-37.pyc', 'op_util.cpython-37.pyc', 'rtrip.cpython-37.pyc', 'source_repr.cpython-37.pyc', 'string_repr.cpython-37.pyc', 'tree_walk.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\astor-0.8.1.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['AUTHORS', 'INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL', 'zip-safe']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\backports
#
# Sub Folders ➞ ['zoneinfo', '__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\backports\zoneinfo
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['py.typed', '_common.py', '_czoneinfo.cp37-win_amd64.pyd', '_tzpath.py', '_version.py', '_zoneinfo.py', '__init__.py', '__init__.pyi']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\backports\zoneinfo\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['_common.cpython-37.pyc', '_tzpath.cpython-37.pyc', '_version.cpython-37.pyc', '_zoneinfo.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\backports\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\backports.zoneinfo-0.2.1.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['INSTALLER', 'LICENSE', 'LICENSE_APACHE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\beautifulsoup4-4.10.0.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['AUTHORS', 'COPYING.txt', 'INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\bs4
#
# Sub Folders ➞ ['builder', '__pycache__']
#
# Files ➞ ['dammit.py', 'diagnose.py', 'element.py', 'formatter.py', 'testing.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\bs4\builder
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['_html5lib.py', '_htmlparser.py', '_lxml.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\bs4\builder\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['_html5lib.cpython-37.pyc', '_htmlparser.cpython-37.pyc', '_lxml.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\bs4\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['dammit.cpython-37.pyc', 'diagnose.cpython-37.pyc', 'element.cpython-37.pyc', 'formatter.cpython-37.pyc', 'testing.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\cached_property-1.5.2.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['AUTHORS.rst', 'INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\cachetools
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['cache.py', 'fifo.py', 'func.py', 'keys.py', 'lfu.py', 'lru.py', 'mru.py', 'rr.py', 'ttl.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\cachetools\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['cache.cpython-37.pyc', 'fifo.cpython-37.pyc', 'func.cpython-37.pyc', 'keys.cpython-37.pyc', 'lfu.cpython-37.pyc', 'lru.cpython-37.pyc', 'mru.cpython-37.pyc', 'rr.cpython-37.pyc', 'ttl.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\cachetools-4.2.4.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2
#
# Sub Folders ➞ ['contrib', 'core', 'distributed', 'experiments', 'perfkernels', 'proto', 'python', 'quantization', '__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib
#
# Sub Folders ➞ ['aten', 'gloo', 'nccl', 'nnpack', 'playground', 'prof', 'script', 'tensorboard', 'warpctc', '__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\aten
#
# Sub Folders ➞ ['docs', '__pycache__']
#
# Files ➞ ['aten_test.py', 'gen_op.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\aten\docs
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['sample.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\aten\docs\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['sample.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\aten\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['aten_test.cpython-37.pyc', 'gen_op.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\gloo
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['gloo_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\gloo\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['gloo_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\nccl
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['nccl_ops_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\nccl\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['nccl_ops_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\nnpack
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['nnpack_ops_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\nnpack\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['nnpack_ops_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\playground
#
# Sub Folders ➞ ['resnetdemo', '__pycache__']
#
# Files ➞ ['AnyExp.py', 'AnyExpOnTerm.py', 'checkpoint.py', 'compute_loss.py', 'compute_topk_accuracy.py', 'meter.py', 'ModuleRegister.py', 'module_map.py', 'output_generator.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\playground\resnetdemo
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['caffe2_resnet50_default_forward.py', 'caffe2_resnet50_default_param_update.py', 'explicit_resnet_forward.py', 'explicit_resnet_param_update.py', 'gfs_IN1k.py', 'IN1k_resnet.py', 'IN1k_resnet_no_test_model.py', 'override_no_test_model_no_checkpoint.py', 'rendezvous_filestore.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\playground\resnetdemo\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['caffe2_resnet50_default_forward.cpython-37.pyc', 'caffe2_resnet50_default_param_update.cpython-37.pyc', 'explicit_resnet_forward.cpython-37.pyc', 'explicit_resnet_param_update.cpython-37.pyc', 'gfs_IN1k.cpython-37.pyc', 'IN1k_resnet.cpython-37.pyc', 'IN1k_resnet_no_test_model.cpython-37.pyc', 'override_no_test_model_no_checkpoint.cpython-37.pyc', 'rendezvous_filestore.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\playground\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['AnyExp.cpython-37.pyc', 'AnyExpOnTerm.cpython-37.pyc', 'checkpoint.cpython-37.pyc', 'compute_loss.cpython-37.pyc', 'compute_topk_accuracy.cpython-37.pyc', 'meter.cpython-37.pyc', 'ModuleRegister.cpython-37.pyc', 'module_map.cpython-37.pyc', 'output_generator.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\prof
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['cuda_profile_ops_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\prof\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['cuda_profile_ops_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\script
#
# Sub Folders ➞ ['examples', '__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\script\examples
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\script\examples\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\script\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\tensorboard
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['tensorboard.py', 'tensorboard_exporter.py', 'tensorboard_exporter_test.py', 'tensorboard_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\tensorboard\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['tensorboard.cpython-37.pyc', 'tensorboard_exporter.cpython-37.pyc', 'tensorboard_exporter_test.cpython-37.pyc', 'tensorboard_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\warpctc
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['ctc_ops_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\warpctc\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['ctc_ops_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\contrib\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\core
#
# Sub Folders ➞ ['nomnigraph', '__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\core\nomnigraph
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['op_gen.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\core\nomnigraph\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['op_gen.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\core\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\distributed
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['file_store_handler_op_test.py', 'redis_store_handler_op_test.py', 'store_ops_test_util.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\distributed\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['file_store_handler_op_test.cpython-37.pyc', 'redis_store_handler_op_test.cpython-37.pyc', 'store_ops_test_util.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\experiments
#
# Sub Folders ➞ ['python', '__pycache__']
#
# Files ➞ ['__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\experiments\python
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['convnet_benchmarks.py', 'device_reduce_sum_bench.py', 'funhash_op_test.py', 'net_construct_bench.py', 'SparseTransformer.py', 'sparse_funhash_op_test.py', 'sparse_reshape_op_test.py', 'tt_contraction_op_test.py', 'tt_pad_op_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\experiments\python\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['convnet_benchmarks.cpython-37.pyc', 'device_reduce_sum_bench.cpython-37.pyc', 'funhash_op_test.cpython-37.pyc', 'net_construct_bench.cpython-37.pyc', 'SparseTransformer.cpython-37.pyc', 'sparse_funhash_op_test.cpython-37.pyc', 'sparse_reshape_op_test.cpython-37.pyc', 'tt_contraction_op_test.cpython-37.pyc', 'tt_pad_op_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\experiments\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\perfkernels
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['hp_emblookup_codegen.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\perfkernels\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['hp_emblookup_codegen.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\proto
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['caffe2_legacy_pb2.py', 'caffe2_pb2.py', 'gen_proto_typestubs_helper.py', 'hsm_pb2.py', 'metanet_pb2.py', 'predictor_consts_pb2.py', 'prof_dag_pb2.py', 'torch_pb2.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\proto\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['caffe2_legacy_pb2.cpython-37.pyc', 'caffe2_pb2.cpython-37.pyc', 'gen_proto_typestubs_helper.cpython-37.pyc', 'hsm_pb2.cpython-37.pyc', 'metanet_pb2.cpython-37.pyc', 'predictor_consts_pb2.cpython-37.pyc', 'prof_dag_pb2.cpython-37.pyc', 'torch_pb2.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python
#
# Sub Folders ➞ ['docs', 'examples', 'fakelowp', 'helpers', 'ideep', 'layers', 'mint', 'mkl', 'modeling', 'models', 'onnx', 'operator_test', 'predictor', 'rnn', 'serialized_test', 'test', 'trt', '__pycache__']
#
# Files ➞ ['allcompare_test.py', 'attention.py', 'benchmark_generator.py', 'binarysize.py', 'brew.py', 'brew_test.py', 'build.py', 'cached_reader.py', 'caffe2_pybind11_state.cp37-win_amd64.pyd', 'caffe_translator.py', 'caffe_translator_test.py', 'checkpoint.py', 'checkpoint_test.py', 'cnn.py', 'context.py', 'context_test.py', 'control.py', 'control_ops_grad.py', 'control_ops_grad_test.py', 'control_ops_util.py', 'control_test.py', 'convert.py', 'convert_test.py', 'convnet_benchmarks.py', 'convnet_benchmarks_test.py', 'core.py', 'core_gradients_test.py', 'core_test.py', 'crf.py', 'crf_predict.py', 'crf_viterbi_test.py', 'dataio.py', 'dataio_test.py', 'dataset.py', 'data_parallel_model.py', 'data_parallel_model_test.py', 'data_workers.py', 'data_workers_test.py', 'db_file_reader.py', 'db_test.py', 'device_checker.py', 'dyndep.py', 'embedding_generation_benchmark.py', 'experiment_util.py', 'extension_loader.py', 'fakefp16_transform_lib.py', 'filler_test.py', 'functional.py', 'functional_test.py', 'fused_8bit_rowwise_conversion_ops_test.py', 'gradient_checker.py', 'gradient_check_test.py', 'gru_cell.py', 'hip_test_util.py', 'hsm_util.py', 'hypothesis_test.py', 'hypothesis_test_util.py', 'ideep_test_util.py', 'layers_test.py', 'layer_model_helper.py', 'layer_model_instantiator.py', 'layer_parameter_sharing_test.py', 'layer_test_util.py', 'lazy.py', 'lazy_dyndep.py', 'lazy_dyndep_test.py', 'lengths_reducer_fused_8bit_rowwise_ops_test.py', 'lengths_reducer_rowwise_8bit_ops_test.py', 'lstm_benchmark.py', 'memonger.py', 'memonger_test.py', 'mkl_test_util.py', 'model_device_test.py', 'model_helper.py', 'model_helper_test.py', 'modifier_context.py', 'muji.py', 'muji_test.py', 'net_builder.py', 'net_builder_test.py', 'net_drawer.py', 'net_printer.py', 'net_printer_test.py', 'nomnigraph.py', 'nomnigraph_test.py', 'nomnigraph_transformations.py', 'nomnigraph_transformations_test.py', 'normalizer.py', 'normalizer_context.py', 'normalizer_test.py', 'numa_benchmark.py', 'numa_test.py', 'observer_test.py', 'operator_fp_exceptions_test.py', 'optimizer.py', 'optimizer_context.py', 'optimizer_test.py', 'optimizer_test_util.py', 'parallelize_bmuf_distributed_test.py', 'parallel_workers.py', 'parallel_workers_test.py', 'pipeline.py', 'pipeline_test.py', 'predictor_constants.py', 'python_op_test.py', 'queue_util.py', 'record_queue.py', 'recurrent.py', 'regularizer.py', 'regularizer_context.py', 'regularizer_test.py', 'rnn_cell.py', 'schema.py', 'schema_test.py', 'scope.py', 'scope_test.py', 'session.py', 'session_test.py', 'sparse_to_dense_mask_test.py', 'sparse_to_dense_test.py', 'task.py', 'task_test.py', 'test_util.py', 'text_file_reader.py', 'timeout_guard.py', 'toy_regression_test.py', 'transformations.py', 'transformations_test.py', 'tt_core.py', 'tt_core_test.py', 'utils.py', 'utils_test.py', 'visualize.py', 'workspace.py', 'workspace_test.py', '_import_c_extension.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\docs
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['formatter.py', 'generator.py', 'github.py', 'parser.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\docs\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['formatter.cpython-37.pyc', 'generator.cpython-37.pyc', 'github.cpython-37.pyc', 'parser.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\examples
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['char_rnn.py', 'imagenet_trainer.py', 'lmdb_create_example.py', 'resnet50_trainer.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\examples\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['char_rnn.cpython-37.pyc', 'imagenet_trainer.cpython-37.pyc', 'lmdb_create_example.cpython-37.pyc', 'resnet50_trainer.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\fakelowp
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['init_shared_libs.py', 'test_utils.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\fakelowp\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['init_shared_libs.cpython-37.pyc', 'test_utils.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\helpers
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['algebra.py', 'arg_scope.py', 'array_helpers.py', 'control_ops.py', 'conv.py', 'db_input.py', 'dropout.py', 'elementwise_linear.py', 'fc.py', 'nonlinearity.py', 'normalization.py', 'pooling.py', 'quantization.py', 'tools.py', 'train.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\helpers\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['algebra.cpython-37.pyc', 'arg_scope.cpython-37.pyc', 'array_helpers.cpython-37.pyc', 'control_ops.cpython-37.pyc', 'conv.cpython-37.pyc', 'db_input.cpython-37.pyc', 'dropout.cpython-37.pyc', 'elementwise_linear.cpython-37.pyc', 'fc.cpython-37.pyc', 'nonlinearity.cpython-37.pyc', 'normalization.cpython-37.pyc', 'pooling.cpython-37.pyc', 'quantization.cpython-37.pyc', 'tools.cpython-37.pyc', 'train.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\ideep
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['adam_op_test.py', 'blobs_queue_db_test.py', 'channel_shuffle_op_test.py', 'concat_split_op_test.py', 'convfusion_op_test.py', 'conv_op_test.py', 'conv_transpose_test.py', 'copy_op_test.py', 'dropout_op_test.py', 'elementwise_sum_op_test.py', 'expanddims_squeeze_op_test.py', 'fc_op_test.py', 'leaky_relu_op_test.py', 'LRN_op_test.py', 'moment_sgd_op_test.py', 'operator_fallback_op_test.py', 'order_switch_op_test.py', 'pool_op_test.py', 'pre_convert_test.py', 'relu_op_test.py', 'reshape_op_test.py', 'shape_op_test.py', 'sigmoid_op_test.py', 'softmax_op_test.py', 'spatial_bn_op_test.py', 'test_ideep_net.py', 'transform_ideep_net.py', 'transpose_op_test.py', 'weightedsum_op_test.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\ideep\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['adam_op_test.cpython-37.pyc', 'blobs_queue_db_test.cpython-37.pyc', 'channel_shuffle_op_test.cpython-37.pyc', 'concat_split_op_test.cpython-37.pyc', 'convfusion_op_test.cpython-37.pyc', 'conv_op_test.cpython-37.pyc', 'conv_transpose_test.cpython-37.pyc', 'copy_op_test.cpython-37.pyc', 'dropout_op_test.cpython-37.pyc', 'elementwise_sum_op_test.cpython-37.pyc', 'expanddims_squeeze_op_test.cpython-37.pyc', 'fc_op_test.cpython-37.pyc', 'leaky_relu_op_test.cpython-37.pyc', 'LRN_op_test.cpython-37.pyc', 'moment_sgd_op_test.cpython-37.pyc', 'operator_fallback_op_test.cpython-37.pyc', 'order_switch_op_test.cpython-37.pyc', 'pool_op_test.cpython-37.pyc', 'pre_convert_test.cpython-37.pyc', 'relu_op_test.cpython-37.pyc', 'reshape_op_test.cpython-37.pyc', 'shape_op_test.cpython-37.pyc', 'sigmoid_op_test.cpython-37.pyc', 'softmax_op_test.cpython-37.pyc', 'spatial_bn_op_test.cpython-37.pyc', 'test_ideep_net.cpython-37.pyc', 'transform_ideep_net.cpython-37.pyc', 'transpose_op_test.cpython-37.pyc', 'weightedsum_op_test.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\layers
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['adaptive_weight.py', 'add_bias.py', 'arc_cosine_feature_map.py', 'batch_huber_loss.py', 'batch_lr_loss.py', 'batch_mse_loss.py', 'batch_normalization.py', 'batch_sigmoid_cross_entropy_loss.py', 'batch_softmax_loss.py', 'blob_weighted_sum.py', 'bpr_loss.py', 'bucket_weighted.py', 'build_index.py', 'concat.py', 'constant_weight.py', 'conv.py', 'dropout.py', 'fc.py', 'fc_without_bias.py', 'fc_with_bootstrap.py', 'feature_sparse_to_dense.py', 'functional.py', 'gather_record.py', 'homotopy_weight.py', 'label_smooth.py', 'last_n_window_collector.py', 'layers.py', 'layer_normalization.py', 'margin_rank_loss.py', 'merge_id_lists.py', 'pairwise_similarity.py', 'position_weighted.py', 'random_fourier_features.py', 'reservoir_sampling.py', 'sampling_train.py', 'sampling_trainable_mixin.py', 'select_record_by_context.py', 'semi_random_features.py', 'sparse_dropout_with_replacement.py', 'sparse_feature_hash.py', 'sparse_itemwise_dropout_with_replacement.py', 'sparse_lookup.py', 'split.py', 'tags.py', 'uniform_sampling.py', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\caffe2\python\layers\__pycache__
#
# Sub Folders ➞ []
#
# ...
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\shell\demos\servers\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['column_provider.cpython-37.pyc', 'context_menu.cpython-37.pyc', 'copy_hook.cpython-37.pyc', 'empty_volume_cache.cpython-37.pyc', 'folder_view.cpython-37.pyc', 'icon_handler.cpython-37.pyc', 'shell_view.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\shell\demos\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['browse_for_folder.cpython-37.pyc', 'create_link.cpython-37.pyc', 'dump_link.cpython-37.pyc', 'explorer_browser.cpython-37.pyc', 'IActiveDesktop.cpython-37.pyc', 'IFileOperationProgressSink.cpython-37.pyc', 'IShellLinkDataList.cpython-37.pyc', 'ITransferAdviseSink.cpython-37.pyc', 'IUniformResourceLocator.cpython-37.pyc', 'shellexecuteex.cpython-37.pyc', 'viewstate.cpython-37.pyc', 'walk_shell_folders.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\shell\test
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['testShellFolder.py', 'testShellItem.py', 'testSHFileOperation.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\shell\test\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['testShellFolder.cpython-37.pyc', 'testShellItem.cpython-37.pyc', 'testSHFileOperation.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\shell\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['shellcon.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\taskscheduler
#
# Sub Folders ➞ ['test', '__pycache__']
#
# Files ➞ ['taskscheduler.pyd', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\taskscheduler\test
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['test_addtask.py', 'test_addtask_1.py', 'test_addtask_2.py', 'test_localsystem.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\taskscheduler\test\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['test_addtask.cpython-37.pyc', 'test_addtask_1.cpython-37.pyc', 'test_addtask_2.cpython-37.pyc', 'test_localsystem.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\win32comext\taskscheduler\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\wrapt
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['decorators.py', 'importer.py', 'wrappers.py', '_wrappers.cp37-win_amd64.pyd', '__init__.py']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\wrapt\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['decorators.cpython-37.pyc', 'importer.cpython-37.pyc', 'wrappers.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\wrapt-1.13.3.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\zipp-3.6.0.dist-info
#
# Sub Folders ➞ []
#
# Files ➞ ['INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Lib\site-packages\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['cached_property.cpython-37.pyc', 'cycler.cpython-37.pyc', 'docopt.cpython-37.pyc', 'kavenegar.cpython-37.pyc', 'pylab.cpython-37.pyc', 'pythoncom.cpython-37.pyc', 'six.cpython-37.pyc', 'termcolor.cpython-37.pyc', 'typing_extensions.cpython-37.pyc', 'zipp.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Scripts
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['clear_comtypes_cache.py', 'convert-caffe2-to-onnx.exe', 'convert-onnx-to-caffe2.exe', 'estimator_ckpt_converter.exe', 'f2py.exe', 'flask.exe', 'fonttools.exe', 'google-oauthlib-tool.exe', 'imageio_download_bin.exe', 'imageio_remove_bin.exe', 'lsm2bin.exe', 'markdown_py.exe', 'normalizer.exe', 'pipwin.exe', 'pyftmerge.exe', 'pyftsubset.exe', 'pyrsa-decrypt.exe', 'pyrsa-encrypt.exe', 'pyrsa-keygen.exe', 'pyrsa-priv2pub.exe', 'pyrsa-sign.exe', 'pyrsa-verify.exe', 'pywin32_postinstall.py', 'pywin32_testall.py', 'saved_model_cli.exe', 'skivi.exe', 'tensorboard.exe', 'tflite_convert.exe', 'tf_upgrade_v2.exe', 'tiff2fsspec.exe', 'tiffcomment.exe', 'tifffile.exe', 'toco.exe', 'toco_from_protos.exe', 'torchrun.exe', 'tqdm.exe', 'ttx.exe', 'wheel.exe']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\Scripts\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['clear_comtypes_cache.cpython-37.pyc', 'pywin32_postinstall.cpython-37.pyc', 'pywin32_testall.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share
#
# Sub Folders ➞ ['doc', 'man']
#
# Files ➞ []
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc
#
# Sub Folders ➞ ['networkx-2.6.3']
#
# Files ➞ []
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3
#
# Sub Folders ➞ ['examples']
#
# Files ➞ ['LICENSE.txt']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples
#
# Sub Folders ➞ ['3d_drawing', 'algorithms', 'basic', 'drawing', 'graph', 'subclass']
#
# Files ➞ ['README.txt']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\3d_drawing
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['mayavi2_spring.py', 'plot_basic.py', 'README.txt']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\3d_drawing\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['mayavi2_spring.cpython-37.pyc', 'plot_basic.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\algorithms
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['hartford_drug.edgelist', 'plot_beam_search.py', 'plot_betweenness_centrality.py', 'plot_blockmodel.py', 'plot_circuits.py', 'plot_davis_club.py', 'plot_dedensification.py', 'plot_iterated_dynamical_systems.py', 'plot_krackhardt_centrality.py', 'plot_parallel_betweenness.py', 'plot_rcm.py', 'plot_snap.py', 'README.txt', 'WormNet.v3.benchmark.txt']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\algorithms\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['plot_beam_search.cpython-37.pyc', 'plot_betweenness_centrality.cpython-37.pyc', 'plot_blockmodel.cpython-37.pyc', 'plot_circuits.cpython-37.pyc', 'plot_davis_club.cpython-37.pyc', 'plot_dedensification.cpython-37.pyc', 'plot_iterated_dynamical_systems.cpython-37.pyc', 'plot_krackhardt_centrality.cpython-37.pyc', 'plot_parallel_betweenness.cpython-37.pyc', 'plot_rcm.cpython-37.pyc', 'plot_snap.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\basic
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['plot_properties.py', 'plot_read_write.py', 'plot_simple_graph.py', 'README.txt']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\basic\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['plot_properties.cpython-37.pyc', 'plot_read_write.cpython-37.pyc', 'plot_simple_graph.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\drawing
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['chess_masters_WCC.pgn.bz2', 'knuth_miles.txt.gz', 'plot_chess_masters.py', 'plot_custom_node_icons.py', 'plot_degree.py', 'plot_directed.py', 'plot_edge_colormap.py', 'plot_ego_graph.py', 'plot_eigenvalues.py', 'plot_four_grids.py', 'plot_house_with_colors.py', 'plot_knuth_miles.py', 'plot_labels_and_colors.py', 'plot_multipartite_graph.py', 'plot_node_colormap.py', 'plot_rainbow_coloring.py', 'plot_random_geometric_graph.py', 'plot_sampson.py', 'plot_selfloops.py', 'plot_simple_path.py', 'plot_spectral_grid.py', 'plot_unix_email.py', 'plot_weighted_graph.py', 'README.txt', 'unix_email.mbox']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\drawing\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['plot_chess_masters.cpython-37.pyc', 'plot_custom_node_icons.cpython-37.pyc', 'plot_degree.cpython-37.pyc', 'plot_directed.cpython-37.pyc', 'plot_edge_colormap.cpython-37.pyc', 'plot_ego_graph.cpython-37.pyc', 'plot_eigenvalues.cpython-37.pyc', 'plot_four_grids.cpython-37.pyc', 'plot_house_with_colors.cpython-37.pyc', 'plot_knuth_miles.cpython-37.pyc', 'plot_labels_and_colors.cpython-37.pyc', 'plot_multipartite_graph.cpython-37.pyc', 'plot_node_colormap.cpython-37.pyc', 'plot_rainbow_coloring.cpython-37.pyc', 'plot_random_geometric_graph.cpython-37.pyc', 'plot_sampson.cpython-37.pyc', 'plot_selfloops.cpython-37.pyc', 'plot_simple_path.cpython-37.pyc', 'plot_spectral_grid.cpython-37.pyc', 'plot_unix_email.cpython-37.pyc', 'plot_weighted_graph.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\graph
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['plot_degree_sequence.py', 'plot_erdos_renyi.py', 'plot_expected_degree_sequence.py', 'plot_football.py', 'plot_karate_club.py', 'plot_napoleon_russian_campaign.py', 'plot_roget.py', 'plot_words.py', 'README.txt', 'roget_dat.txt.gz', 'words_dat.txt.gz']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\graph\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['plot_degree_sequence.cpython-37.pyc', 'plot_erdos_renyi.cpython-37.pyc', 'plot_expected_degree_sequence.cpython-37.pyc', 'plot_football.cpython-37.pyc', 'plot_karate_club.cpython-37.pyc', 'plot_napoleon_russian_campaign.cpython-37.pyc', 'plot_roget.cpython-37.pyc', 'plot_words.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\subclass
#
# Sub Folders ➞ ['__pycache__']
#
# Files ➞ ['plot_antigraph.py', 'plot_printgraph.py', 'README.txt']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\doc\networkx-2.6.3\examples\subclass\__pycache__
#
# Sub Folders ➞ []
#
# Files ➞ ['plot_antigraph.cpython-37.pyc', 'plot_printgraph.cpython-37.pyc']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\man
#
# Sub Folders ➞ ['man1']
#
# Files ➞ []
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
# Folder Name ➞ C:\Users\vasudha\AppData\Local\Programs\Python\Python37\share\man\man1
#
# Sub Folders ➞ []
#
# Files ➞ ['ttx.1']
#
# Files copied successfully from C:\Users\vasudha\AppData\Local\Programs\Python\Python37 to C:\Users\vasudha\AppData\Local\Programs\Python\Python36
